# %%
# !pip install pandas numpy scikit-learn

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
# Out:
# Collecting pandas
#   Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Using cached numpy-2.3.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\ml project\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\ml project\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 3.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.0 MB 5.9 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/11.0 MB 6.5 MB/s eta 0:00:02
#    -------------------- ------------------- 5.5/11.0 MB 6.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.0 MB 6.3 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 6.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 6.1 MB/s eta 0:00:00
# Using cached numpy-2.3.1-cp313-cp313-win_amd64.whl (12.7 MB)
# Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/10.7 MB 7.2 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/10.7 MB 7.0 MB/s eta 0:00:02
#    -------------- ------------------------- 3.9/10.7 MB 6.4 MB/s eta 0:00:02
#    ------------------ --------------------- 5.0/10.7 MB 6.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.0/10.7 MB 5.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.7 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.7 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.7 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.7 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.7 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.7 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.7 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.7 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.7 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.7 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 3.2 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading scipy-1.16.0-cp313-cp313-win_amd64.whl (38.4 MB)
#    ---------------------------------------- 0.0/38.4 MB ? eta -:--:--
#    - -------------------------------------- 1.3/38.4 MB 6.5 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/38.4 MB 6.3 MB/s eta 0:00:06
#    --- ------------------------------------ 3.7/38.4 MB 6.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/38.4 MB 5.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/38.4 MB 5.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/38.4 MB 5.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/38.4 MB 5.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/38.4 MB 5.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/38.4 MB 5.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/38.4 MB 5.9 MB/s eta 0:00:06
#    ------ --------------------------------- 6.6/38.4 MB 2.8 MB/s eta 0:00:12
#    ------- -------------------------------- 7.3/38.4 MB 2.9 MB/s eta 0:00:11
#    --------- ------------------------------ 8.7/38.4 MB 3.1 MB/s eta 0:00:10
#    --------- ------------------------------ 9.4/38.4 MB 3.2 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.0/38.4 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.0/38.4 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.0/38.4 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.0/38.4 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.0/38.4 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.0/38.4 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.0/38.4 MB 3.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 10.7/38.4 MB 2.3 MB/s eta 0:00:13
#    ------------ --------------------------- 11.8/38.4 MB 2.4 MB/s eta 0:00:11
#    ------------ --------------------------- 11.8/38.4 MB 2.4 MB/s eta 0:00:11
#    ------------- -------------------------- 12.6/38.4 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 13.9/38.4 MB 2.5 MB/s eta 0:00:10
#    --------------- ------------------------ 14.9/38.4 MB 2.6 MB/s eta 0:00:09
#    ---------------- ----------------------- 16.0/38.4 MB 2.7 MB/s eta 0:00:09
#    ----------------- ---------------------- 16.8/38.4 MB 2.7 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.8/38.4 MB 2.7 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.8/38.4 MB 2.7 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.8/38.4 MB 2.7 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.8/38.4 MB 2.7 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.8/38.4 MB 2.7 MB/s eta 0:00:08
#    ------------------ --------------------- 17.3/38.4 MB 2.3 MB/s eta 0:00:10
#    -------------------- ------------------- 19.7/38.4 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 20.7/38.4 MB 2.6 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.8/38.4 MB 2.7 MB/s eta 0:00:07
#    ----------------------- ---------------- 22.5/38.4 MB 2.7 MB/s eta 0:00:06
#    ------------------------ --------------- 23.6/38.4 MB 2.8 MB/s eta 0:00:06
#    ------------------------- -------------- 24.6/38.4 MB 2.8 MB/s eta 0:00:05
#    -------------------------- ------------- 25.4/38.4 MB 2.9 MB/s eta 0:00:05
#    --------------------------- ------------ 26.5/38.4 MB 2.9 MB/s eta 0:00:05
#    ---------------------------- ----------- 27.0/38.4 MB 2.9 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.6/38.4 MB 3.0 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.6/38.4 MB 3.0 MB/s eta 0:00:04
#    -------------------------------- ------- 31.2/38.4 MB 3.1 MB/s eta 0:00:03
#    --------------------------------- ------ 32.5/38.4 MB 3.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.3/38.4 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 35.4/38.4 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.4 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 38.4/38.4 MB 3.5 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, numpy, joblib, scipy, pandas, scikit-learn
#
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ---------------------------------------- 8/8 [scikit-learn]
#
# Successfully installed joblib-1.5.1 numpy-2.3.1 pandas-2.3.1 pytz-2025.2 scikit-learn-1.7.0 scipy-1.16.0 threadpoolctl-3.6.0 tzdata-2025.2

# %%
# Load dataset
df = pd.read_csv("sample_student_dataset.csv")

# Preview first few rows
df.head()
# Out:
#   StudentID  Attendance  InternalMarks  StudyHoursPerWeek Participation  \
# 0      S001          90             69                  9           Yes
# 1      S002          57             64                 13            No
# 2      S003          51             57                  3            No
# 3      S004          97             99                  9           Yes
# 4      S005          67             80                 15           Yes
#
#   Extracurricular FinalResult
# 0             Yes        Fail
# 1              No        Pass
# 2              No        Fail
# 3             Yes        Pass
# 4              No        Pass

# %%
# Check for missing values
print(df.isnull().sum())

# Drop or fill missing values if any (for this sample dataset, it's clean)
# df.dropna(inplace=True)  # if you want to drop rows with missing values
# df.fillna(method="ffill", inplace=True)  # or forward fill
# Out:
# StudentID            0
# Attendance           0
# InternalMarks        0
# StudyHoursPerWeek    0
# Participation        0
# Extracurricular      0
# FinalResult          0
# dtype: int64

# %%
# Encode Participation and Extracurricular columns (Yes/No → 1/0)
df['Participation'] = df['Participation'].map({'Yes': 1, 'No': 0})
df['Extracurricular'] = df['Extracurricular'].map({'Yes': 1, 'No': 0})

# Encode FinalResult (Pass/Fail) as target
label_encoder = LabelEncoder()
df['FinalResult'] = label_encoder.fit_transform(df['FinalResult'])  # Pass = 1, Fail = 0

# %%
X = df.drop(columns=["StudentID", "FinalResult"])
y = df["FinalResult"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert back to DataFrame (optional, useful for analysis)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled_df.head()
# Out:
#    Attendance  InternalMarks  StudyHoursPerWeek  Participation  \
# 0    1.088821      -0.102682           0.241481       0.886405
# 1   -1.108799      -0.392745           1.119595      -1.128152
# 2   -1.508367      -0.798832          -1.075690      -1.128152
# 3    1.554983       1.637693           0.241481       0.886405
# 4   -0.442854       0.535455           1.558652       0.886405
#
#    Extracurricular
# 0         0.960769
# 1        -1.040833
# 2        -1.040833
# 3         0.960769
# 4        -1.040833

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.5
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.50      0.55        12
#            1       0.40      0.50      0.44         8
#
#     accuracy                           0.50        20
#    macro avg       0.50      0.50      0.49        20
# weighted avg       0.52      0.50      0.51        20
#
# Confusion Matrix:
#  [[6 6]
#  [4 4]]

# %%
import joblib

# Save model
joblib.dump(model, "student_model.pkl")

# Save scaler
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']
